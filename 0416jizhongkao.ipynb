# %% [markdown]
# <a href="https://colab.research.google.com/github/4070E113/security2021/blob/main/0416jizhongkao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = {"name" : "Eric", "age" : 90}
print(type(a))
# Out:
# <class 'dict'>

# %%
thisislist = [1,2,3,4,5]
print(type(thisislist))
# Out:
# <class 'list'>

# %%
word = "arttarataaa"
print(type(word))
# Out:
# <class 'str'>

# %%
thisislist = [1,2,3,4,5]
print(thisislist[-4])
# Out:
# 2

# %%
thisislist = [1,2,3,4,5]
print(thisislist[1:4])
# Out:
# [2, 3, 4]

# %%
print("3*2*(17-2)")
# Out:
# 3*2*(17-2)

# %%
print(3*2*(17-2))
# Out:
# 90

# %%
print("abc""+""def")
# Out:
# abc+def

# %%
print("abc"+"def")
# Out:
# abcdef

# %%
word = "arttarataaa"
print(word.replace("a", "z",3))
# Out:
# zrttzrztaaa

# %%
word = "arttarataaa"
print(word.replace("a", "z"))
# Out:
# zrttzrztzzz

# %%
thisisdict1 = dict(a="1", b="2", c=3)
thisisdict1.pop("b")
print(thisisdict1)
# Out:
# {'a': '1', 'c': 3}

# %%
if 0:
    print("Hello")

# %%
if 100 == "100":
    print("Hello")

# %%
x = 10
if x >= 10:
  if x > 20:
    print("1")
  else:
    print("2")
# Out:
# 2

# %%
x = 10
if x > 10:
  if x >= 20:
    print("1")
  else:
    print("2")

# %%
for x in [0, 1, 2,3]:
  if x == 2:
print(x)
# Out:
#   File "<ipython-input-34-5e437c17311f>", line 3
#     print(x)
#             ^
# IndentationError: expected an indented block

# %%
i = 100
a = 0
while i >= 1 :
  a += i
  i += -1
print(a)
# Out:
# 5050

# %%
i = 100
while i >= 1 :
  a =0
  a += i
  i += -1
print(a)
# Out:
# 1

# %%
i = 20
while i == 20:
  print("ok")
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ...

# %%
i = 10
while i < 15:
  i += 1
  if i >= 13:
    continue
  print(i)
# Out:
# 11
# 12
